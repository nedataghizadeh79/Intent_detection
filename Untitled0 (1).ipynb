# %% [markdown]
# Please God let this be the end of this NLP Course! A M E N

# %% [markdown]
# <div dir="rtl">
# <h1>
# طبقه‌بندی کلمات با استفاده از مدل HMM
# </h1>
#
# در این نوتبوک، با استفاده از دیتاست
# <a href="https://huggingface.co/datasets/AmazonScience/massive/viewer/fa-IR"> آمازون </a>
# به طبقه‌بندی کلمات می‌پردازیم. بدین شکل که تک تک کلمات مهم قصدشان شناسایی می‌شود یا none طلقی می شوند.
# </div>

# %%
! pip uninstall numpy
! pip install datasets hazm numpy
! pip install numpy
# Out:
# Found existing installation: numpy 1.25.2
# Uninstalling numpy-1.25.2:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/f2py3
#     /usr/local/bin/f2py3.10
#     /usr/local/lib/python3.10/dist-packages/numpy-1.25.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libgfortran-040039e1.so.5.0.0
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libopenblas64_p-r0-5007b62f.3.23.dev.so
#     /usr/local/lib/python3.10/dist-packages/numpy.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.10/dist-packages/numpy/*
# Proceed (Y/n)? y
#   Successfully uninstalled numpy-1.25.2
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.14.4)
# Requirement already satisfied: hazm in /usr/local/lib/python3.10/dist-packages (0.9.3)
# Collecting numpy
#   Using cached numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.3.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: fasttext-wheel<0.10.0,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from hazm) (0.9.2)
# Requirement already satisfied: gensim<5.0.0,>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from hazm) (4.3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from hazm) (3.8.1)
# Requirement already satisfied: python-crfsuite<0.10.0,>=0.9.9 in /usr/local/lib/python3.10/dist-packages (from hazm) (0.9.9)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from hazm) (1.2.2)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (2.11.1)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (67.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (6.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (2023.6.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.2.2->hazm) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.2 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.25.2 which is incompatible.
# Successfully installed numpy-1.25.2
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)

# %%
import numpy as np
import pandas as pd
import random
import time
from pprint import pprint
from datasets import load_dataset
from hazm import WordTokenizer

# %%
dataset = load_dataset("AmazonScience/massive", 'fa-IR')
# Out:
# Downloading builder script:   0%|          | 0.00/30.3k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/34.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/40.3M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
pprint(dataset['train'][0])
# Out:
# {'annot_utt': 'مرا [date : جمعه] ساعت [time : نه صبح] بیدار کن',
#  'id': '1',
#  'intent': 48,
#  'judgments': {'grammar_score': [4, 4, 4],
#                'intent_score': [1, 1, 1],
#                'language_identification': ['target', 'target', 'target'],
#                'slots_score': [1, 1, 1],
#                'spelling_score': [2, 2, 2],
#                'worker_id': ['3', '8', '14']},
#  'locale': 'fa-IR',
#  'partition': 'train',
#  'scenario': 16,
#  'slot_method': {'method': ['translation', 'translation'],
#                  'slot': ['time', 'date']},
#  'utt': 'مرا جمعه ساعت نه صبح بیدار کن',
#  'worker_id': '3'}

# %% [markdown]
# <br>
# <h2 dir="rtl">
# برای این که از داده‌های دیتاست استفاده کنیم، نیاز است تا هر داده را به صورت
# (word, label)
# درآوریم
# </h2>

# %%
import re

def extract_bracket_parts(text):
    pattern = r'\[([^:]+)\s*:\s*([^]]+)\]'
    matches = re.findall(pattern, text)

    extracted_parts = []
    for match in matches:
        before_colon = match[0].strip()
        after_colon = match[1].strip()
        extracted_parts.append((before_colon, after_colon))

    return extracted_parts

# %% [markdown]
# این تابع، نسخه‌ی برچسب خورده و بدون برچسب یک جمله را می‌گیرد (مطابق حالتی که در دیتاست داریم) و سپس با فرمتی که در داک تمرین خواسته شده، به صورت لیستی از تاپل‌های (کلمه، برچسب) باز می‌گرداند

# %%
tokenizer = WordTokenizer()

def get_word_tag_tuples(utt: str, annot_utt: str):
  tokens = tokenizer.tokenize(utt)
  dic = {token: (None, index) for index, token in enumerate(tokens)}
  tagged_parts = extract_bracket_parts(annot_utt)
  for part in tagged_parts:
    tag = part[0]
    words = tokenizer.tokenize(part[1])
    for w in words:
      try:
        dic[w] = (tag, dic[w][1])
      except KeyError:
        # Sometimes hazm tokenizer doesn't do a very good job!
        return []
  sorted_parts = sorted(dic.items(), key=lambda x: x[1][1])
  return [(key, value[0]) for key, value in sorted_parts]

# %%
d = dataset['train'][0]
get_word_tag_tuples(d['utt'], d['annot_utt'])
# Out:
# [('مرا', None),
#  ('جمعه', 'date'),
#  ('ساعت', None),
#  ('نه', 'time'),
#  ('صبح', 'time'),
#  ('بیدار', None),
#  ('کن', None)]

# %%
train_tagged_words = [get_word_tag_tuples(d['utt'], d['annot_utt']) for d in dataset['train']]
train_tagged_words = [l for l in train_tagged_words if l]

# %%
print(train_tagged_words[0])
print(len(dataset['train']))
print(len(train_tagged_words))
# Out:
# [('مرا', None), ('جمعه', 'date'), ('ساعت', None), ('نه', 'time'), ('صبح', 'time'), ('بیدار', None), ('کن', None)]
# 11514
# 11506

# %%
train_tagged_words_unstructured = [x for sublist in train_tagged_words for x in sublist]

# %%
all_tags = {tag for all_tags in train_tagged_words for _, tag in all_tags}
print(all_tags)
vocab = {word for all_words in train_tagged_words for word, _ in all_words }
len(vocab)
# Out:
# {'definition_word', 'movie_name', 'color_type', 'player_setting', 'news_topic', 'device_type', 'list_name', 'radio_name', 'audiobook_name', 'currency_name', 'time_zone', 'cooking_type', 'sport_type', 'playlist_name', 'joke_type', 'audiobook_author', 'timeofday', 'game_type', 'place_name', 'person', 'song_name', 'food_type', 'music_genre', 'business_name', 'event_name', 'coffee_type', 'relation', 'transport_name', None, 'business_type', 'date', 'weather_descriptor', 'time', 'transport_type', 'order_type', 'meal_type', 'artist_name', 'change_amount', 'media_type', 'drink_type', 'music_album', 'alarm_type', 'movie_type', 'email_folder', 'email_address', 'house_place', 'app_name', 'podcast_descriptor', 'transport_descriptor', 'transport_agency', 'podcast_name', 'game_name', 'music_descriptor', 'personal_info', 'general_frequency', 'ingredient'}
# 5689

# %% [markdown]
# <h2 dir="rtl">
# پایان آماده‌سازی دیتاست
# </h2>
# <br>
# <hr>
# <br>
# <h2 dir="rtl">
# الگوریتم Viterbi
# </h2>

# %% [markdown]
# محاسبه‌ی احتمال emission

# %%
def word_given_tag(word, tag, train_bag):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)#total number of times the passed tag occurred in train_bag
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
#now calculate the total number of times the passed word occurred as the passed tag.
    count_w_given_tag = len(w_given_tag_list)


    return (count_w_given_tag, count_tag)

# %% [markdown]
# محاسبه‌ی احتمال transition

# %%
def t2_given_t1(t2, t1, train_bag):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %% [markdown]
# محاسبه‌ی ماتریس transition

# %%
tags_matrix = np.zeros((len(all_tags), len(all_tags)), dtype='float32')
for i, t1 in enumerate(list(all_tags)):
    for j, t2 in enumerate(list(all_tags)):
        res = t2_given_t1(t2, t1, train_tagged_words_unstructured)
        tags_matrix[i, j] = res[0]/res[1]

print(tags_matrix)
# Out:
# [[0.3058104  0.         0.         ... 0.         0.         0.        ]
#  [0.         0.516129   0.         ... 0.         0.         0.        ]
#  [0.         0.         0.11607143 ... 0.         0.         0.        ]
#  ...
#  [0.         0.         0.         ... 0.45255473 0.         0.        ]
#  [0.         0.         0.         ... 0.         0.4909091  0.        ]
#  [0.         0.         0.         ... 0.         0.         0.33333334]]

# %% [markdown]
# ماتریس احتمالات تگ‌ها

# %%
tags_df = pd.DataFrame(tags_matrix, columns = list(all_tags), index=list(all_tags))
display(tags_df)
# Out:
#                       definition_word  movie_name  color_type  player_setting  \
# definition_word              0.305810    0.000000    0.000000        0.000000
# movie_name                   0.000000    0.516129    0.000000        0.000000
# color_type                   0.000000    0.000000    0.116071        0.000000
# player_setting               0.000000    0.000000    0.000000        0.623737
# news_topic                   0.000000    0.000000    0.000000        0.000000
# device_type                  0.000000    0.000000    0.000000        0.000000
# list_name                    0.000000    0.000000    0.000000        0.000000
# radio_name                   0.000000    0.000000    0.000000        0.000000
# audiobook_name               0.000000    0.000000    0.000000        0.025862
# currency_name                0.006601    0.000000    0.000000        0.000000
# time_zone                    0.000000    0.000000    0.000000        0.000000
# cooking_type                 0.000000    0.000000    0.000000        0.000000
# sport_type                   0.000000    0.000000    0.000000        0.000000
# playlist_name                0.000000    0.000000    0.000000        0.000000
# joke_type                    0.000000    0.000000    0.000000        0.000000
# audiobook_author             0.000000    0.000000    0.000000        0.125000
# timeofday                    0.000000    0.000000    0.000000        0.000000
# game_type                    0.000000    0.000000    0.000000        0.000000
# place_name                   0.000000    0.000000    0.000000        0.000000
# person                       0.000000    0.000000    0.000000        0.000000
# song_name                    0.000000    0.000000    0.000000        0.000000
# food_type                    0.000000    0.000000    0.000000        0.000000
# music_genre                  0.000000    0.000000    0.000000        0.000000
# business_name                0.000000    0.000000    0.000000        0.000000
# event_name                   0.000000    0.000000    0.000000        0.000000
# coffee_type                  0.000000    0.000000    0.000000        0.000000
# relation                     0.000000    0.000000    0.000000        0.000000
# transport_name               0.000000    0.000000    0.000000        0.000000
# None                         0.003421    0.000228    0.001490        0.002098
# business_type                0.000000    0.000000    0.000000        0.000000
# date                         0.000000    0.000000    0.000000        0.000000
# weather_descriptor           0.000000    0.000000    0.000000        0.000000
# time                         0.000000    0.000000    0.000000        0.000563
# transport_type               0.000000    0.000000    0.000000        0.000000
# order_type                   0.000000    0.000000    0.000000        0.000000
# meal_type                    0.000000    0.000000    0.000000        0.000000
# artist_name                  0.000000    0.000000    0.000000        0.003086
# change_amount                0.000000    0.000000    0.000000        0.000000
# media_type                   0.000000    0.000000    0.000000        0.002445
# drink_type                   0.000000    0.000000    0.000000        0.000000
# music_album                  0.000000    0.000000    0.000000        0.000000
# alarm_type                   0.000000    0.000000    0.000000        0.000000
# movie_type                   0.000000    0.000000    0.000000        0.000000
# email_folder                 0.000000    0.000000    0.000000        0.000000
# email_address                0.000000    0.000000    0.000000        0.000000
# house_place                  0.000000    0.000000    0.003922        0.000000
# app_name                     0.000000    0.000000    0.000000        0.032787
# podcast_descriptor           0.000000    0.000000    0.000000        0.006494
# transport_descriptor         0.000000    0.000000    0.000000        0.000000
# transport_agency             0.000000    0.000000    0.000000        0.000000
# podcast_name                 0.000000    0.000000    0.000000        0.000000
# game_name                    0.000000    0.000000    0.000000        0.000000
# music_descriptor             0.000000    0.000000    0.000000        0.000000
# personal_info                0.000000    0.000000    0.000000        0.000000
# general_frequency            0.000000    0.000000    0.000000        0.000000
# ingredient                   0.000000    0.000000    0.000000        0.000000
#
#                       news_topic  device_type  list_name  radio_name  \
# definition_word         0.000000     0.000000   0.000000    0.000000
# movie_name              0.000000     0.000000   0.000000    0.000000
# color_type              0.000000     0.000000   0.000000    0.000000
# player_setting          0.000000     0.002525   0.000000    0.000000
# news_topic              0.485465     0.000000   0.000000    0.000000
# device_type             0.000000     0.461358   0.000000    0.000000
# list_name               0.000000     0.000000   0.383648    0.000000
# radio_name              0.000000     0.000000   0.000000    0.511111
# audiobook_name          0.000000     0.000000   0.000000    0.000000
# currency_name           0.000000     0.000000   0.000000    0.000000
# time_zone               0.000000     0.000000   0.000000    0.000000
# cooking_type            0.000000     0.000000   0.000000    0.000000
# sport_type              0.000000     0.000000   0.000000    0.000000
# playlist_name           0.000000     0.000000   0.000000    0.000000
# joke_type               0.000000     0.000000   0.000000    0.000000
# audiobook_author        0.000000     0.000000   0.000000    0.000000
# timeofday               0.000000     0.000000   0.000000    0.000000
# game_type               0.000000     0.000000   0.000000    0.000000
# place_name              0.000000     0.000000   0.000000    0.000000
# person                  0.000859     0.000000   0.000000    0.000000
# song_name               0.000000     0.000000   0.000000    0.000000
# food_type               0.000000     0.000000   0.000000    0.000000
# music_genre             0.000000     0.000000   0.000000    0.000000
# business_name           0.000000     0.000000   0.000000    0.000000
# event_name              0.000000     0.000000   0.000000    0.000000
# coffee_type             0.000000     0.000000   0.000000    0.000000
# relation                0.000000     0.000000   0.000000    0.000000
# transport_name          0.000000     0.000000   0.000000    0.000000
# None                    0.002600     0.003391   0.002919    0.001977
# business_type           0.000000     0.000000   0.000000    0.000000
# date                    0.001491     0.000745   0.001491    0.000000
# weather_descriptor      0.002070     0.000000   0.000000    0.000000
# time                    0.000000     0.001688   0.000000    0.000563
# transport_type          0.000000     0.000000   0.000000    0.000000
# order_type              0.000000     0.000000   0.000000    0.000000
# meal_type               0.000000     0.000000   0.000000    0.000000
# artist_name             0.000000     0.000000   0.000000    0.000000
# change_amount           0.000000     0.000000   0.000000    0.000000
# media_type              0.000000     0.000000   0.000000    0.000000
# drink_type              0.000000     0.000000   0.000000    0.000000
# music_album             0.000000     0.000000   0.000000    0.000000
# alarm_type              0.000000     0.000000   0.000000    0.000000
# movie_type              0.000000     0.000000   0.000000    0.000000
# email_folder            0.000000     0.000000   0.000000    0.000000
# email_address           0.000000     0.000000   0.000000    0.000000
# house_place             0.000000     0.003922   0.000000    0.003922
# app_name                0.000000     0.000000   0.000000    0.000000
# podcast_descriptor      0.000000     0.000000   0.000000    0.000000
# transport_descriptor    0.000000     0.000000   0.000000    0.000000
# transport_agency        0.000000     0.000000   0.000000    0.000000
# podcast_name            0.000000     0.000000   0.000000    0.000000
# game_name               0.000000     0.000000   0.000000    0.000000
# music_descriptor        0.000000     0.000000   0.000000    0.000000
# personal_info           0.000000     0.000000   0.000000    0.000000
# general_frequency       0.000000     0.000000   0.000000    0.000000
# ingredient              0.000000     0.000000   0.000000    0.000000
#
#                       audiobook_name  currency_name  ...  app_name  \
# definition_word             0.000000       0.000000  ...  0.000000
# movie_name                  0.000000       0.000000  ...  0.000000
# color_type                  0.000000       0.000000  ...  0.000000
# player_setting              0.027778       0.000000  ...  0.005051
# news_topic                  0.000000       0.000000  ...  0.000000
# device_type                 0.000000       0.000000  ...  0.002342
# list_name                   0.000000       0.000000  ...  0.000000
# radio_name                  0.000000       0.000000  ...  0.000000
# audiobook_name              0.370690       0.000000  ...  0.000000
# currency_name               0.000000       0.310231  ...  0.000000
# time_zone                   0.000000       0.000000  ...  0.000000
# cooking_type                0.000000       0.000000  ...  0.000000
# sport_type                  0.000000       0.000000  ...  0.000000
# playlist_name               0.000000       0.000000  ...  0.000000
# joke_type                   0.000000       0.000000  ...  0.000000
# audiobook_author            0.000000       0.000000  ...  0.000000
# timeofday                   0.000000       0.000000  ...  0.000000
# game_type                   0.000000       0.000000  ...  0.000000
# place_name                  0.000000       0.000000  ...  0.000000
# person                      0.000000       0.000000  ...  0.000000
# song_name                   0.000000       0.000000  ...  0.000000
# food_type                   0.000000       0.000000  ...  0.000000
# music_genre                 0.000000       0.000000  ...  0.000000
# business_name               0.000000       0.000000  ...  0.000000
# event_name                  0.000000       0.000000  ...  0.000000
# coffee_type                 0.000000       0.000000  ...  0.000000
# relation                    0.000000       0.000000  ...  0.000000
# transport_name              0.000000       0.000000  ...  0.000000
# None                        0.000775       0.003178  ...  0.000715
# business_type               0.000000       0.000000  ...  0.000000
# date                        0.000000       0.000000  ...  0.000000
# weather_descriptor          0.000000       0.000000  ...  0.000000
# time                        0.000000       0.000000  ...  0.000000
# transport_type              0.000000       0.000000  ...  0.000000
# order_type                  0.000000       0.000000  ...  0.000000
# meal_type                   0.000000       0.000000  ...  0.000000
# artist_name                 0.000000       0.000000  ...  0.000000
# change_amount               0.000000       0.000000  ...  0.000000
# media_type                  0.012225       0.000000  ...  0.000000
# drink_type                  0.000000       0.000000  ...  0.000000
# music_album                 0.000000       0.000000  ...  0.000000
# alarm_type                  0.000000       0.000000  ...  0.000000
# movie_type                  0.000000       0.000000  ...  0.000000
# email_folder                0.000000       0.000000  ...  0.000000
# email_address               0.000000       0.000000  ...  0.000000
# house_place                 0.000000       0.000000  ...  0.000000
# app_name                    0.016393       0.000000  ...  0.163934
# podcast_descriptor          0.000000       0.000000  ...  0.000000
# transport_descriptor        0.000000       0.000000  ...  0.000000
# transport_agency            0.000000       0.000000  ...  0.000000
# podcast_name                0.000000       0.000000  ...  0.000000
# game_name                   0.000000       0.000000  ...  0.000000
# music_descriptor            0.000000       0.000000  ...  0.010204
# personal_info               0.000000       0.000000  ...  0.000000
# general_frequency           0.000000       0.000000  ...  0.000000
# ingredient                  0.000000       0.000000  ...  0.000000
#
#                       podcast_descriptor  transport_descriptor  \
# definition_word                 0.000000              0.000000
# movie_name                      0.000000              0.000000
# color_type                      0.000000              0.000000
# player_setting                  0.002525              0.000000
# news_topic                      0.000000              0.000000
# device_type                     0.000000              0.000000
# list_name                       0.000000              0.000000
# radio_name                      0.000000              0.000000
# audiobook_name                  0.000000              0.000000
# currency_name                   0.000000              0.000000
# time_zone                       0.000000              0.000000
# cooking_type                    0.000000              0.000000
# sport_type                      0.000000              0.000000
# playlist_name                   0.000000              0.000000
# joke_type                       0.000000              0.000000
# audiobook_author                0.000000              0.000000
# timeofday                       0.000000              0.000000
# game_type                       0.000000              0.000000
# place_name                      0.000000              0.000707
# person                          0.000000              0.000000
# song_name                       0.000000              0.000000
# food_type                       0.000000              0.000000
# music_genre                     0.000000              0.000000
# business_name                   0.000000              0.000000
# event_name                      0.000000              0.000000
# coffee_type                     0.000000              0.000000
# relation                        0.000000              0.000000
# transport_name                  0.000000              0.000000
# None                            0.000958              0.000076
# business_type                   0.000000              0.000000
# date                            0.000000              0.000000
# weather_descriptor              0.000000              0.000000
# time                            0.000000              0.000000
# transport_type                  0.000000              0.006410
# order_type                      0.000000              0.000000
# meal_type                       0.000000              0.000000
# artist_name                     0.000000              0.000000
# change_amount                   0.000000              0.000000
# media_type                      0.000000              0.000000
# drink_type                      0.000000              0.000000
# music_album                     0.000000              0.000000
# alarm_type                      0.000000              0.000000
# movie_type                      0.000000              0.000000
# email_folder                    0.000000              0.000000
# email_address                   0.000000              0.000000
# house_place                     0.000000              0.000000
# app_name                        0.000000              0.000000
# podcast_descriptor              0.571429              0.000000
# transport_descriptor            0.000000              0.652174
# transport_agency                0.000000              0.000000
# podcast_name                    0.023810              0.000000
# game_name                       0.000000              0.000000
# music_descriptor                0.000000              0.000000
# personal_info                   0.000000              0.000000
# general_frequency               0.000000              0.000000
# ingredient                      0.000000              0.000000
#
#                       transport_agency  podcast_name  game_name  \
# definition_word               0.000000      0.000000   0.000000
# movie_name                    0.000000      0.000000   0.000000
# color_type                    0.000000      0.000000   0.000000
# player_setting                0.000000      0.000000   0.000000
# news_topic                    0.000000      0.000000   0.000000
# device_type                   0.000000      0.000000   0.000000
# list_name                     0.000000      0.000000   0.000000
# radio_name                    0.000000      0.000000   0.000000
# audiobook_name                0.000000      0.000000   0.000000
# currency_name                 0.000000      0.000000   0.000000
# time_zone                     0.000000      0.000000   0.000000
# cooking_type                  0.000000      0.000000   0.000000
# sport_type                    0.000000      0.000000   0.000000
# playlist_name                 0.000000      0.000000   0.000000
# joke_type                     0.000000      0.000000   0.000000
# audiobook_author              0.000000      0.000000   0.000000
# timeofday                     0.000000      0.000000   0.000000
# game_type                     0.000000      0.000000   0.000000
# place_name                    0.000707      0.000000   0.000000
# person                        0.000000      0.000000   0.000000
# song_name                     0.000000      0.000000   0.000000
# food_type                     0.000000      0.000000   0.000000
# music_genre                   0.000000      0.000000   0.000000
# business_name                 0.000000      0.000000   0.000000
# event_name                    0.000000      0.000000   0.000000
# coffee_type                   0.000000      0.000000   0.000000
# relation                      0.000000      0.000000   0.000000
# transport_name                0.000000      0.000000   0.000000
# None                          0.000426      0.000745   0.001277
# business_type                 0.000000      0.000000   0.000000
# date                          0.000000      0.000000   0.000000
# weather_descriptor            0.000000      0.000000   0.000000
# time                          0.000563      0.000000   0.000000
# transport_type                0.003205      0.000000   0.000000
# order_type                    0.000000      0.000000   0.000000
# meal_type                     0.000000      0.000000   0.000000
# artist_name                   0.000000      0.000000   0.000000
# change_amount                 0.000000      0.000000   0.000000
# media_type                    0.000000      0.000000   0.000000
# drink_type                    0.000000      0.000000   0.000000
# music_album                   0.000000      0.000000   0.000000
# alarm_type                    0.000000      0.000000   0.000000
# movie_type                    0.000000      0.000000   0.000000
# email_folder                  0.000000      0.000000   0.000000
# email_address                 0.000000      0.000000   0.000000
# house_place                   0.000000      0.000000   0.000000
# app_name                      0.000000      0.000000   0.000000
# podcast_descriptor            0.000000      0.045455   0.000000
# transport_descriptor          0.000000      0.000000   0.000000
# transport_agency              0.031250      0.000000   0.000000
# podcast_name                  0.000000      0.333333   0.000000
# game_name                     0.000000      0.000000   0.382353
# music_descriptor              0.000000      0.000000   0.000000
# personal_info                 0.000000      0.000000   0.000000
# general_frequency             0.000000      0.000000   0.000000
# ingredient                    0.000000      0.000000   0.000000
#
#                       music_descriptor  personal_info  general_frequency  \
# definition_word               0.000000       0.000000           0.000000
# movie_name                    0.000000       0.000000           0.000000
# color_type                    0.000000       0.000000           0.000000
# player_setting                0.000000       0.000000           0.000000
# news_topic                    0.000000       0.000000           0.000000
# device_type                   0.000000       0.000000           0.000000
# list_name                     0.000000       0.000000           0.000000
# radio_name                    0.000000       0.000000           0.000000
# audiobook_name                0.000000       0.000000           0.000000
# currency_name                 0.000000       0.000000           0.000000
# time_zone                     0.000000       0.000000           0.000000
# cooking_type                  0.000000       0.000000           0.000000
# sport_type                    0.000000       0.000000           0.000000
# playlist_name                 0.005587       0.000000           0.000000
# joke_type                     0.000000       0.000000           0.000000
# audiobook_author              0.000000       0.000000           0.000000
# timeofday                     0.000000       0.000000           0.000000
# game_type                     0.000000       0.000000           0.000000
# place_name                    0.000000       0.000000           0.000000
# person                        0.000000       0.001718           0.000000
# song_name                     0.000000       0.000000           0.000000
# food_type                     0.000000       0.000000           0.000000
# music_genre                   0.004444       0.000000           0.000000
# business_name                 0.000000       0.000000           0.000000
# event_name                    0.000000       0.000000           0.005047
# coffee_type                   0.000000       0.000000           0.000000
# relation                      0.000000       0.000000           0.000000
# transport_name                0.000000       0.000000           0.000000
# None                          0.000623       0.001110           0.000988
# business_type                 0.000000       0.000000           0.000000
# date                          0.000373       0.000000           0.001864
# weather_descriptor            0.002070       0.000000           0.000000
# time                          0.000000       0.000000           0.003376
# transport_type                0.000000       0.000000           0.000000
# order_type                    0.000000       0.000000           0.000000
# meal_type                     0.000000       0.000000           0.000000
# artist_name                   0.003086       0.000000           0.000000
# change_amount                 0.000000       0.000000           0.000000
# media_type                    0.000000       0.000000           0.000000
# drink_type                    0.000000       0.000000           0.000000
# music_album                   0.000000       0.000000           0.000000
# alarm_type                    0.000000       0.000000           0.000000
# movie_type                    0.000000       0.000000           0.000000
# email_folder                  0.000000       0.000000           0.000000
# email_address                 0.000000       0.000000           0.000000
# house_place                   0.000000       0.000000           0.000000
# app_name                      0.000000       0.000000           0.000000
# podcast_descriptor            0.000000       0.000000           0.000000
# transport_descriptor          0.000000       0.000000           0.000000
# transport_agency              0.000000       0.000000           0.000000
# podcast_name                  0.000000       0.000000           0.000000
# game_name                     0.000000       0.000000           0.000000
# music_descriptor              0.530612       0.000000           0.000000
# personal_info                 0.000000       0.452555           0.000000
# general_frequency             0.000000       0.000000           0.490909
# ingredient                    0.000000       0.000000           0.000000
#
#                       ingredient
# definition_word         0.000000
# movie_name              0.000000
# color_type              0.000000
# player_setting          0.000000
# news_topic              0.000000
# device_type             0.000000
# list_name               0.000000
# radio_name              0.000000
# audiobook_name          0.000000
# currency_name           0.000000
# time_zone               0.000000
# cooking_type            0.047619
# sport_type              0.000000
# playlist_name           0.000000
# joke_type               0.000000
# audiobook_author        0.000000
# timeofday               0.000000
# game_type               0.000000
# place_name              0.000000
# person                  0.000000
# song_name               0.000000
# food_type               0.000000
# music_genre             0.000000
# business_name           0.000000
# event_name              0.000000
# coffee_type             0.000000
# relation                0.000000
# transport_name          0.000000
# None                    0.000289
# business_type           0.000000
# date                    0.000000
# weather_descriptor      0.000000
# time                    0.000000
# transport_type          0.000000
# order_type              0.000000
# meal_type               0.000000
# artist_name             0.000000
# change_amount           0.000000
# media_type              0.000000
# drink_type              0.000000
# music_album             0.000000
# alarm_type              0.000000
# movie_type              0.000000
# email_folder            0.000000
# email_address           0.000000
# house_place             0.000000
# app_name                0.000000
# podcast_descriptor      0.000000
# transport_descriptor    0.000000
# transport_agency        0.000000
# podcast_name            0.000000
# game_name               0.000000
# music_descriptor        0.000000
# personal_info           0.000000
# general_frequency       0.000000
# ingredient              0.333333
#
# [56 rows x 56 columns]

# %%
def viterbi(words, train_bag):
    state = []
    T = list(set([pair[1] for pair in train_bag]))

    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = []
        for tag in T:
            if key == 0:
                transition_p = 1  # tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]

            # compute emission and state probabilities
            prb = word_given_tag(words[key], tag, train_tagged_words_unstructured)
            emission_p = prb[0]/prb[1]
            state_probability = emission_p * transition_p
            p.append(state_probability)

        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)]
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# <br>
# <hr>
#
# <h1 dir="rtl">
# تست
# <h1>
# <h6 dir="rtl">
# پیاده‌سازی به اتمام رسیده. با صدا زدن تابع viterbi می‌توانیم خروجی مدل را مشاهده کنیم.
# </h2>

# %%
test = dataset['test'][0]
print(test['utt'])

print('what we want: ', test['annot_utt'])
print('our result: ', viterbi(tokenizer.tokenize(test['utt']), train_tagged_words_unstructured))
# Out:
# این هفته ساعت پنج صبح بیدارم کن
# what we want:  [date : این هفته] ساعت [time : پنج صبح] بیدارم کن
# our result:  [('این', 'date'), ('هفته', 'date'), ('ساعت', None), ('پنج', 'time'), ('صبح', 'time'), ('بیدارم', None), ('کن', None)]

# %%
def measure_accuracy(test_size: int = len(dataset['test'])):
  total, total_correct = 0, 0

  start = time.time()

  for i in range(test_size):
    test_data = dataset['test'][i]
    tagged_answer = get_word_tag_tuples(test_data['utt'], test_data['annot_utt'])
    our_result = viterbi(tokenizer.tokenize(test_data['utt']), train_tagged_words_unstructured)
    total_correct += len([i for i, j in zip(our_result, tagged_answer) if i == j])
    total += len(our_result)

  end = time.time()
  difference = end-start

  accuracy = total_correct/total
  print('Viterbi Algorithm Accuracy: ',accuracy*100)
  print(f' ** took {difference} second! **')



measure_accuracy(100)
# Out:
# Viterbi Algorithm Accuracy:  71.81964573268921
#  ** took 185.10642218589783 second! **

# %%
import tqdm


def measure_accuracy_long(test_size: int = len(dataset['test'])):
  total, total_correct = 0, 0

  start = time.time()

  for i in tqdm.tqdm(range(test_size)):
    test_data = dataset['test'][i]
    tagged_answer = get_word_tag_tuples(test_data['utt'], test_data['annot_utt'])
    our_result = viterbi(tokenizer.tokenize(test_data['utt']), train_tagged_words_unstructured)
    total_correct += len([i for i, j in zip(our_result, tagged_answer) if i == j])
    total += len(our_result)

  end = time.time()
  difference = end-start

  accuracy = total_correct/total
  print('\nViterbi Algorithm Accuracy: ',accuracy*100)
  print(f' ** took {difference} second! **')

# %%
measure_accuracy_long()
# Out:
# 100%|██████████| 2974/2974 [1:51:43<00:00,  2.25s/it]
# Viterbi Algorithm Accuracy:  69.61270190895742
#  ** took 6703.436355829239 second! **
